# %% [markdown]
# <font color=Green>
#
# # **3.3 Operaciones con DataFrames**
#
# </font>

# %%
import numpy as np
import pandas as pd

# %%
d = [np.random.randint(50,size=(10))]
d
# Out:
# [array([20, 49, 39, 35, 21,  6,  2,  2,  7, 27])]

# %%
df = pd.DataFrame(d).T #cambiar la fila por columna
df
# Out:
#     0
# 0  20
# 1  49
# 2  39
# 3  35
# 4  21
# 5   6
# 6   2
# 7   2
# 8   7
# 9  27

# %% [markdown]
# ## <font color=#003d5c>_Añadir una nueva columna_ </font>

# %%
df['nueva_col'] = 10 #con valor asignado

# %%
df['experiencia'] = 5 #con valor asignado

df
# Out:
#     0  nueva_col  experiencia
# 0  20         10            5
# 1  49         10            5
# 2  39         10            5
# 3  35         10            5
# 4  21         10            5
# 5   6         10            5
# 6   2         10            5
# 7   2         10            5
# 8   7         10            5
# 9  27         10            5

# %%
df['perdidas'] = [(i+2)*np.e for i in range(10)] 
#columna perdidas es igual a i+2 * np.e para cada elemento i dentro del rango 0 al 10
#numpy.e es el número de Euler, representado por la constante matemática 𝑒, 
# aproximadamente igual a 2.718281828459045
df
# Out:
#     0  nueva_col  experiencia   perdidas
# 0  20         10            5   5.436564
# 1  49         10            5   8.154845
# 2  39         10            5  10.873127
# 3  35         10            5  13.591409
# 4  21         10            5  16.309691
# 5   6         10            5  19.027973
# 6   2         10            5  21.746255
# 7   2         10            5  24.464536
# 8   7         10            5  27.182818
# 9  27         10            5  29.901100

# %%
df['columna'] = df['perdidas']*100
df
# Out:
#     0  nueva_col  experiencia   perdidas      columna
# 0  20         10            5   5.436564   543.656366
# 1  49         10            5   8.154845   815.484549
# 2  39         10            5  10.873127  1087.312731
# 3  35         10            5  13.591409  1359.140914
# 4  21         10            5  16.309691  1630.969097
# 5   6         10            5  19.027973  1902.797280
# 6   2         10            5  21.746255  2174.625463
# 7   2         10            5  24.464536  2446.453646
# 8   7         10            5  27.182818  2718.281828
# 9  27         10            5  29.901100  2990.110011

# %% [markdown]
# ## <font color=#003d5c>_Cambiar el nombre de una columna_ </font>

# %%
df.columns
# Out:
# Index([0, 'nueva_col', 'experiencia', 'perdidas', 'columna'], dtype='object')

# %%
df.columns = ['codigo_id','años_exp', 'indice', 'eficiencia','eficiencia_agregada']

df
# Out:
#    codigo_id  años_exp  indice  eficiencia  eficiencia_agregada
# 0         20        10       5    5.436564           543.656366
# 1         49        10       5    8.154845           815.484549
# 2         39        10       5   10.873127          1087.312731
# 3         35        10       5   13.591409          1359.140914
# 4         21        10       5   16.309691          1630.969097
# 5          6        10       5   19.027973          1902.797280
# 6          2        10       5   21.746255          2174.625463
# 7          2        10       5   24.464536          2446.453646
# 8          7        10       5   27.182818          2718.281828
# 9         27        10       5   29.901100          2990.110011

# %%
df['codigo_id']
# Out:
# 0    20
# 1    49
# 2    39
# 3    35
# 4    21
# 5     6
# 6     2
# 7     2
# 8     7
# 9    27
# Name: codigo_id, dtype: int32

# %% [markdown]
# ## <font color=#003d5c>_Modificar una columna_ </font>

# %%
df['indice'] = df['indice'] / 200

df
# Out:
#    codigo_id  años_exp  indice  eficiencia  eficiencia_agregada
# 0         20        10   0.025    5.436564           543.656366
# 1         49        10   0.025    8.154845           815.484549
# 2         39        10   0.025   10.873127          1087.312731
# 3         35        10   0.025   13.591409          1359.140914
# 4         21        10   0.025   16.309691          1630.969097
# 5          6        10   0.025   19.027973          1902.797280
# 6          2        10   0.025   21.746255          2174.625463
# 7          2        10   0.025   24.464536          2446.453646
# 8          7        10   0.025   27.182818          2718.281828
# 9         27        10   0.025   29.901100          2990.110011

# %% [markdown]
# ## <font color=#003d5c>_Eliminar una columna o una fila_ </font>

# %%
del df['eficiencia'] #funcion eliminar

df
# Out:
#    codigo_id  años_exp  indice  eficiencia_agregada
# 0         20        10   0.025           543.656366
# 1         49        10   0.025           815.484549
# 2         39        10   0.025          1087.312731
# 3         35        10   0.025          1359.140914
# 4         21        10   0.025          1630.969097
# 5          6        10   0.025          1902.797280
# 6          2        10   0.025          2174.625463
# 7          2        10   0.025          2446.453646
# 8          7        10   0.025          2718.281828
# 9         27        10   0.025          2990.110011

# %%
c = df.drop([2,3,5], axis=0) #elimina (no guarda) con eje 0, filas, con 1 columnas, las que numeramos
c
# Out:
#    codigo_id  años_exp  indice  eficiencia_agregada
# 0         20        10   0.025           543.656366
# 1         49        10   0.025           815.484549
# 4         21        10   0.025          1630.969097
# 6          2        10   0.025          2174.625463
# 7          2        10   0.025          2446.453646
# 8          7        10   0.025          2718.281828
# 9         27        10   0.025          2990.110011

# %%
df
# Out:
#    codigo_id  años_exp  indice  eficiencia_agregada
# 0         20        10   0.025           543.656366
# 1         49        10   0.025           815.484549
# 2         39        10   0.025          1087.312731
# 3         35        10   0.025          1359.140914
# 4         21        10   0.025          1630.969097
# 5          6        10   0.025          1902.797280
# 6          2        10   0.025          2174.625463
# 7          2        10   0.025          2446.453646
# 8          7        10   0.025          2718.281828
# 9         27        10   0.025          2990.110011

# %%
df.drop(['eficiencia_agregada'], axis=1, inplace =  True)

df.head()
# Out:
#    codigo_id  años_exp  indice
# 0         20        10   0.025
# 1         49        10   0.025
# 2         39        10   0.025
# 3         35        10   0.025
# 4         21        10   0.025

# %%
df
# Out:
#    codigo_id  años_exp  indice
# 0         20        10   0.025
# 1         49        10   0.025
# 2         39        10   0.025
# 3         35        10   0.025
# 4         21        10   0.025
# 5          6        10   0.025
# 6          2        10   0.025
# 7          2        10   0.025
# 8          7        10   0.025
# 9         27        10   0.025

# %% [markdown]
# ## <font color=#003d5c>_Modificar el índice_ </font>

# %%
i = ['a','b','c','d','e','f','g','h','i','j']

df.index = i

df
# Out:
#    codigo_id  años_exp  indice
# a         20        10   0.025
# b         49        10   0.025
# c         39        10   0.025
# d         35        10   0.025
# e         21        10   0.025
# f          6        10   0.025
# g          2        10   0.025
# h          2        10   0.025
# i          7        10   0.025
# j         27        10   0.025

# %%
df["codigo_id"].mean()
# Out:
# 20.8

# %%
df["codigo_id"].sum()
# Out:
# 208

# %%
df["codigo_id"].min()
# Out:
# 2

# %%
df["codigo_id"].max()
# Out:
# 49
